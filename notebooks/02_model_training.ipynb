# %%
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from xgboost import XGBClassifier
from pathlib import Path

import sys
from pathlib import Path

project_root = Path.cwd().parents[0]
sys.path.append(str(project_root))

from src.features.feature_engineering import feature_engineering
from src.utils.split_data import split_data
from src.utils.model_helpers import run_grid_search, save_model

# %%
# Load data
df = pd.read_csv("/Users/erik/Documents/GitHub/customer-churn-prediction/data/raw/WA_Fn-UseC_-Telco-Customer-Churn.csv")

# %%
# Feature engineering
X, y = feature_engineering(df)

# Train/test split
X_train, X_test, y_train, y_test = split_data(X, y)

# %%
rf_parameters={
    'n_estimators': [50,100,150,200],
    'max_depth': [None, 10, 20],
    'min_samples_split': [2,5,10],
    'max_features': ['sqrt', 'log2'] 
}

xgb_parameters={
    'max_depth': [3,5,7],
    'learning_rate': [0.1, 0.01, 0.001],
    'subsample': [0.5, 0.7, 1]

}

svm_parameters = {
    'kernel': ['linear', 'rbf', 'poly'],
    'gamma': [0.1, 1, 10],
    'C': [0.1, 1, 10],
    'degree': [2, 3, 4]
}

# %%
rf_model = RandomForestClassifier(random_state=42)
xgb_model = XGBClassifier()
svm_model = SVC()

# %%
models = {
    'Random Forest': {
        'model': rf_model,
        'param': rf_parameters
        },
    'XGBoost': {
        'model': xgb_model,
        'param': xgb_parameters
    },
    'Support Vector Machine': {
        'model': svm_model,
        'param': svm_parameters
    }
}

# %%
results = {}
best_param = {}

for name, config in models.items():
    model = config['model']
    params = config['param']
    print(f"\nRunning GridSearchCV for: {name}")
    grid = run_grid_search(model, params, X_train, y_train)

    best_model = grid.best_estimator_
    y_pred = best_model.predict(X_test)

    f1 = f1_score(y_test, y_pred)

    results[name] = f1
    best_param[name] = grid.best_params_

    save_model(best_model, f"outputs/models/{name.lower().replace(' ', '_')}_tuned.pkl")
# Out:
# Running GridSearchCV for: Random Forest
# Fitting 5 folds for each of 72 candidates, totalling 360 fits
# [CV] END max_depth=None, max_features=sqrt, min_samples_split=2, n_estimators=50; total time=   0.1s
# [CV] END max_depth=None, max_features=sqrt, min_samples_split=2, n_estimators=50; total time=   0.1s
# [CV] END max_depth=None, max_features=sqrt, min_samples_split=2, n_estimators=50; total time=   0.1s
# [CV] END max_depth=None, max_features=sqrt, min_samples_split=2, n_estimators=50; total time=   0.1s
# [CV] END max_depth=None, max_features=sqrt, min_samples_split=2, n_estimators=50; total time=   0.2s
# [CV] END max_depth=None, max_features=sqrt, min_samples_split=2, n_estimators=100; total time=   0.3s
# [CV] END max_depth=None, max_features=sqrt, min_samples_split=2, n_estimators=100; total time=   0.3s
# [CV] END max_depth=None, max_features=sqrt, min_samples_split=2, n_estimators=100; total time=   0.3s
# [CV] END max_depth=None, max_features=sqrt, min_samples_split=2, n_estimators=100; total time=   0.3s
# [CV] END max_depth=None, max_features=sqrt, min_samples_split=2, n_estimators=100; total time=   0.3s
# [CV] END max_depth=None, max_features=sqrt, min_samples_split=2, n_estimators=150; total time=   0.5s
# [CV] END max_depth=None, max_features=sqrt, min_samples_split=2, n_estimators=150; total time=   0.4s
# [CV] END max_depth=None, max_features=sqrt, min_samples_split=2, n_estimators=150; total time=   0.4s
# [CV] END max_depth=None, max_features=sqrt, min_samples_split=5, n_estimators=50; total time=   0.2s
# [CV] END max_depth=None, max_features=sqrt, min_samples_split=2, n_estimators=150; total time=   0.4s
# [CV] END max_depth=None, max_features=sqrt, min_samples_split=5, n_estimators=50; total time=   0.1s
# [CV] END max_depth=None, max_features=sqrt, min_samples_split=2, n_estimators=150; total time=   0.5s
# [CV] END max_depth=None, max_features=sqrt, min_samples_split=5, n_estimators=50; total time=   0.1s
# [CV] END max_depth=None, max_features=sqrt, min_samples_split=5, n_estimators=50; total time=   0.1s
# [CV] END max_depth=None, max_features=sqrt, min_samples_split=5, n_estimators=50; total time=   0.1s
# [CV] END max_depth=None, max_features=sqrt, min_samples_split=2, n_estimators=200; total time=   0.6s
# [CV] END max_depth=None, max_features=sqrt, min_samples_split=2, n_estimators=200; total time=   0.6s
# [CV] END max_depth=None, max_features=sqrt, min_samples_split=5, n_estimators=100; total time=   0.3s
# [CV] END max_depth=None, max_features=sqrt, min_samples_split=5, n_estimators=100; total time=   0.3s
# [CV] END max_depth=None, max_features=sqrt, min_samples_split=5, n_estimators=100; total time=   0.3s
# [CV] END max_depth=None, max_features=sqrt, min_samples_split=5, n_estimators=100; total time=   0.3s
# [CV] END max_depth=None, max_features=sqrt, min_samples_split=5, n_estimators=100; total time=   0.3s
# [CV] END max_depth=None, max_features=sqrt, min_samples_split=2, n_estimators=200; total time=   0.6s
# [CV] END max_depth=None, max_features=sqrt, min_samples_split=2, n_estimators=200; total time=   0.6s
# [CV] END max_depth=None, max_features=sqrt, min_samples_split=2, n_estimators=200; total time=   0.6s
# [CV] END max_depth=None, max_features=sqrt, min_samples_split=5, n_estimators=150; total time=   0.4s
# [CV] END max_depth=None, max_features=sqrt, min_samples_split=10, n_estimators=50; total time=   0.1s
# [CV] END max_depth=None, max_features=sqrt, min_samples_split=10, n_estimators=50; total time=   0.1s
# [CV] END max_depth=None, max_features=sqrt, min_samples_split=5, n_estimators=150; total time=   0.4s
# [CV] END max_depth=None, max_features=sqrt, min_samples_split=5, n_estimators=150; total time=   0.4s
# [CV] END max_depth=None, max_features=sqrt, min_samples_split=10, n_estimators=50; total time=   0.1s
# [CV] END max_depth=None, max_features=sqrt, min_samples_split=10, n_estimators=50; total time=   0.1s
# [CV] END max_depth=None, max_features=sqrt, min_samples_split=5, n_estimators=150; total time=   0.5s
# [CV] END max_depth=None, max_features=sqrt, min_samples_split=10, n_estimators=50; total time=   0.2s
# [CV] END max_depth=None, max_features=sqrt, min_samples_split=5, n_estimators=150; total time=   0.4s
# [CV] END max_depth=None, max_features=sqrt, min_samples_split=10, n_estimators=100; total time=   0.3s
# [CV] END max_depth=None, max_features=sqrt, min_samples_split=5, n_estimators=200; total time=   0.5s
# [CV] END max_depth=None, max_features=sqrt, min_samples_split=5, n_estimators=200; total time=   0.6s
# [CV] END max_depth=None, max_features=sqrt, min_samples_split=10, n_estimators=100; total time=   0.2s
# [CV] END max_depth=None, max_features=sqrt, min_samples_split=5, n_estimators=200; total time=   0.5s
# [CV] END max_depth=None, max_features=sqrt, min_samples_split=5, n_estimators=200; total time=   0.6s
# [CV] END max_depth=None, max_features=sqrt, min_samples_split=10, n_estimators=100; total time=   0.3s
# [CV] END max_depth=None, max_features=sqrt, min_samples_split=5, n_estimators=200; total time=   0.6s
# [CV] END max_depth=None, max_features=sqrt, min_samples_split=10, n_estimators=100; total time=   0.3s
# [CV] END max_depth=None, max_features=sqrt, min_samples_split=10, n_estimators=100; total time=   0.4s
# [CV] END max_depth=None, max_features=sqrt, min_samples_split=10, n_estimators=150; total time=   0.4s
# [CV] END max_depth=None, max_features=sqrt, min_samples_split=10, n_estimators=150; total time=   0.4s
# [CV] END max_depth=None, max_features=log2, min_samples_split=2, n_estimators=50; total time=   0.2s
# [CV] END max_depth=None, max_features=sqrt, min_samples_split=10, n_estimators=150; total time=   0.4s
# [CV] END max_depth=None, max_features=log2, min_samples_split=2, n_estimators=50; total time=   0.2s
# [CV] END max_depth=None, max_features=log2, min_samples_split=2, n_estimators=50; total time=   0.1s
# [CV] END max_depth=None, max_features=log2, min_samples_split=2, n_estimators=50; total time=   0.2s
# [CV] END max_depth=None, max_features=sqrt, min_samples_split=10, n_estimators=150; total time=   0.4s
# [CV] END max_depth=None, max_features=sqrt, min_samples_split=10, n_estimators=150; total time=   0.4s
# [CV] END max_depth=None, max_features=log2, min_samples_split=2, n_estimators=50; total time=   0.1s
# [CV] END max_depth=None, max_features=sqrt, min_samples_split=10, n_estimators=200; total time=   0.5s
# [CV] END max_depth=None, max_features=sqrt, min_samples_split=10, n_estimators=200; total time=   0.5s
# [CV] END max_depth=None, max_features=sqrt, min_samples_split=10, n_estimators=200; total time=   0.5s
# [CV] END max_depth=None, max_features=sqrt, min_samples_split=10, n_estimators=200; total time=   0.5s
# [CV] END max_depth=None, max_features=sqrt, min_samples_split=10, n_estimators=200; total time=   0.5s
# [CV] END max_depth=None, max_features=log2, min_samples_split=2, n_estimators=100; total time=   0.3s
# [CV] END max_depth=None, max_features=log2, min_samples_split=2, n_estimators=100; total time=   0.3s
# [CV] END max_depth=None, max_features=log2, min_samples_split=2, n_estimators=100; total time=   0.3s
# [CV] END max_depth=None, max_features=log2, min_samples_split=2, n_estimators=100; total time=   0.3s
# [CV] END max_depth=None, max_features=log2, min_samples_split=2, n_estimators=100; total time=   0.3s
# [CV] END max_depth=None, max_features=log2, min_samples_split=5, n_estimators=50; total time=   0.1s
# [CV] END max_depth=None, max_features=log2, min_samples_split=5, n_estimators=50; total time=   0.1s
# [CV] END max_depth=None, max_features=log2, min_samples_split=2, n_estimators=150; total time=   0.5s
# [CV] END max_depth=None, max_features=log2, min_samples_split=2, n_estimators=150; total time=   0.4s
# [CV] END max_depth=None, max_features=log2, min_samples_split=2, n_estimators=150; total time=   0.4s
# [CV] END max_depth=None, max_features=log2, min_samples_split=5, n_estimators=50; total time=   0.1s
# [CV] END max_depth=None, max_features=log2, min_samples_split=2, n_estimators=150; total time=   0.4s
# [CV] END max_depth=None, max_features=log2, min_samples_split=5, n_estimators=50; total time=   0.1s
# [CV] END max_depth=None, max_features=log2, min_samples_split=2, n_estimators=150; total time=   0.4s
# [CV] END max_depth=None, max_features=log2, min_samples_split=5, n_estimators=50; total time=   0.1s
# [CV] END max_depth=None, max_features=log2, min_samples_split=5, n_estimators=100; total time=   0.3s
# [CV] END max_depth=None, max_features=log2, min_samples_split=2, n_estimators=200; total time=   0.6s
# [CV] END max_depth=None, max_features=log2, min_samples_split=2, n_estimators=200; total time=   0.6s
# [CV] END max_depth=None, max_features=log2, min_samples_split=5, n_estimators=100; total time=   0.2s
# [CV] END max_depth=None, max_features=log2, min_samples_split=2, n_estimators=200; total time=   0.6s
# [CV] END max_depth=None, max_features=log2, min_samples_split=5, n_estimators=100; total time=   0.3s
# [CV] END max_depth=None, max_features=log2, min_samples_split=2, n_estimators=200; total time=   0.6s
# [CV] END max_depth=None, max_features=log2, min_samples_split=5, n_estimators=100; total time=   0.3s
# [CV] END max_depth=None, max_features=log2, min_samples_split=2, n_estimators=200; total time=   0.6s
# [CV] END max_depth=None, max_features=log2, min_samples_split=5, n_estimators=100; total time=   0.3s
# [CV] END max_depth=None, max_features=log2, min_samples_split=10, n_estimators=50; total time=   0.1s
# [CV] END max_depth=None, max_features=log2, min_samples_split=10, n_estimators=50; total time=   0.1s
# [CV] END max_depth=None, max_features=log2, min_samples_split=5, n_estimators=150; total time=   0.4s
# [CV] END max_depth=None, max_features=log2, min_samples_split=5, n_estimators=150; total time=   0.4s
# [CV] END max_depth=None, max_features=log2, min_samples_split=10, n_estimators=50; total time=   0.1s
# [CV] END max_depth=None, max_features=log2, min_samples_split=10, n_estimators=50; total time=   0.1s
# [CV] END max_depth=None, max_features=log2, min_samples_split=10, n_estimators=50; total time=   0.2s
# [CV] END max_depth=None, max_features=log2, min_samples_split=5, n_estimators=150; total time=   0.4s
# [CV] END max_depth=None, max_features=log2, min_samples_split=5, n_estimators=150; total time=   0.4s
# [CV] END max_depth=None, max_features=log2, min_samples_split=5, n_estimators=150; total time=   0.4s
# [CV] END max_depth=None, max_features=log2, min_samples_split=10, n_estimators=100; total time=   0.3s
# [CV] END max_depth=None, max_features=log2, min_samples_split=5, n_estimators=200; total time=   0.5s
# [CV] END max_depth=None, max_features=log2, min_samples_split=5, n_estimators=200; total time=   0.5s
# [CV] END max_depth=None, max_features=log2, min_samples_split=10, n_estimators=100; total time=   0.2s
# [CV] END max_depth=None, max_features=log2, min_samples_split=5, n_estimators=200; total time=   0.5s
# [CV] END max_depth=None, max_features=log2, min_samples_split=5, n_estimators=200; total time=   0.5s
# [CV] END max_depth=None, max_features=log2, min_samples_split=10, n_estimators=100; total time=   0.2s
# [CV] END max_depth=None, max_features=log2, min_samples_split=5, n_estimators=200; total time=   0.6s
# [CV] END max_depth=None, max_features=log2, min_samples_split=10, n_estimators=100; total time=   0.3s
# [CV] END max_depth=None, max_features=log2, min_samples_split=10, n_estimators=100; total time=   0.3s
# [CV] END max_depth=None, max_features=log2, min_samples_split=10, n_estimators=150; total time=   0.4s
# [CV] END max_depth=10, max_features=sqrt, min_samples_split=2, n_estimators=50; total time=   0.1s
# [CV] END max_depth=10, max_features=sqrt, min_samples_split=2, n_estimators=50; total time=   0.1s
# [CV] END max_depth=None, max_features=log2, min_samples_split=10, n_estimators=150; total time=   0.4s
# [CV] END max_depth=None, max_features=log2, min_samples_split=10, n_estimators=150; total time=   0.3s
# [CV] END max_depth=10, max_features=sqrt, min_samples_split=2, n_estimators=50; total time=   0.1s
# [CV] END max_depth=10, max_features=sqrt, min_samples_split=2, n_estimators=50; total time=   0.1s
# [CV] END max_depth=None, max_features=log2, min_samples_split=10, n_estimators=150; total time=   0.3s
# [CV] END max_depth=10, max_features=sqrt, min_samples_split=2, n_estimators=50; total time=   0.1s
# [CV] END max_depth=None, max_features=log2, min_samples_split=10, n_estimators=150; total time=   0.4s
# [CV] END max_depth=None, max_features=log2, min_samples_split=10, n_estimators=200; total time=   0.4s
# [CV] END max_depth=10, max_features=sqrt, min_samples_split=2, n_estimators=100; total time=   0.2s
# [CV] END max_depth=None, max_features=log2, min_samples_split=10, n_estimators=200; total time=   0.5s
# [CV] END max_depth=None, max_features=log2, min_samples_split=10, n_estimators=200; total time=   0.5s
# [CV] END max_depth=None, max_features=log2, min_samples_split=10, n_estimators=200; total time=   0.5s
# [CV] END max_depth=None, max_features=log2, min_samples_split=10, n_estimators=200; total time=   0.5s
# [CV] END max_depth=10, max_features=sqrt, min_samples_split=2, n_estimators=100; total time=   0.3s
# [CV] END max_depth=10, max_features=sqrt, min_samples_split=2, n_estimators=100; total time=   0.3s
# [CV] END max_depth=10, max_features=sqrt, min_samples_split=2, n_estimators=100; total time=   0.3s
# [CV] END max_depth=10, max_features=sqrt, min_samples_split=2, n_estimators=100; total time=   0.3s
# [CV] END max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=50; total time=   0.1s
# [CV] END max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=50; total time=   0.1s
# [CV] END max_depth=10, max_features=sqrt, min_samples_split=2, n_estimators=150; total time=   0.4s
# [CV] END max_depth=10, max_features=sqrt, min_samples_split=2, n_estimators=150; total time=   0.3s
# [CV] END max_depth=10, max_features=sqrt, min_samples_split=2, n_estimators=150; total time=   0.3s
# [CV] END max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=50; total time=   0.1s
# [CV] END max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=50; total time=   0.1s
# [CV] END max_depth=10, max_features=sqrt, min_samples_split=2, n_estimators=150; total time=   0.5s
# [CV] END max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=50; total time=   0.1s
# [CV] END max_depth=10, max_features=sqrt, min_samples_split=2, n_estimators=150; total time=   0.5s
# [CV] END max_depth=10, max_features=sqrt, min_samples_split=2, n_estimators=200; total time=   0.5s
# [CV] END max_depth=10, max_features=sqrt, min_samples_split=2, n_estimators=200; total time=   0.5s
# [CV] END max_depth=10, max_features=sqrt, min_samples_split=2, n_estimators=200; total time=   0.5s
# [CV] END max_depth=10, max_features=sqrt, min_samples_split=2, n_estimators=200; total time=   0.5s
# [CV] END max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=100; total time=   0.2s
# [CV] END max_depth=10, max_features=sqrt, min_samples_split=2, n_estimators=200; total time=   0.5s
# [CV] END max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=100; total time=   0.2s
# [CV] END max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=100; total time=   0.3s
# [CV] END max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=100; total time=   0.2s
# [CV] END max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=100; total time=   0.2s
# [CV] END max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=150; total time=   0.3s
# [CV] END max_depth=10, max_features=sqrt, min_samples_split=10, n_estimators=50; total time=   0.2s
# [CV] END max_depth=10, max_features=sqrt, min_samples_split=10, n_estimators=50; total time=   0.2s
# [CV] END max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=150; total time=   0.4s
# [CV] END max_depth=10, max_features=sqrt, min_samples_split=10, n_estimators=50; total time=   0.1s
# [CV] END max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=150; total time=   0.4s
# [CV] END max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=150; total time=   0.4s
# [CV] END max_depth=10, max_features=sqrt, min_samples_split=10, n_estimators=50; total time=   0.1s
# [CV] END max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=150; total time=   0.4s
# [CV] END max_depth=10, max_features=sqrt, min_samples_split=10, n_estimators=50; total time=   0.2s
# [CV] END max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=200; total time=   0.5s
# [CV] END max_depth=10, max_features=sqrt, min_samples_split=10, n_estimators=100; total time=   0.2s
# [CV] END max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=200; total time=   0.5s
# [CV] END max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=200; total time=   0.5s
# [CV] END max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=200; total time=   0.5s
# [CV] END max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=200; total time=   0.6s
# [CV] END max_depth=10, max_features=sqrt, min_samples_split=10, n_estimators=100; total time=   0.3s
# [CV] END max_depth=10, max_features=sqrt, min_samples_split=10, n_estimators=100; total time=   0.3s
# [CV] END max_depth=10, max_features=sqrt, min_samples_split=10, n_estimators=100; total time=   0.2s
# [CV] END max_depth=10, max_features=sqrt, min_samples_split=10, n_estimators=100; total time=   0.3s
# [CV] END max_depth=10, max_features=log2, min_samples_split=2, n_estimators=50; total time=   0.1s
# [CV] END max_depth=10, max_features=log2, min_samples_split=2, n_estimators=50; total time=   0.1s
# [CV] END max_depth=10, max_features=sqrt, min_samples_split=10, n_estimators=150; total time=   0.3s
# [CV] END max_depth=10, max_features=sqrt, min_samples_split=10, n_estimators=150; total time=   0.4s
# [CV] END max_depth=10, max_features=log2, min_samples_split=2, n_estimators=50; total time=   0.1s
# [CV] END max_depth=10, max_features=log2, min_samples_split=2, n_estimators=50; total time=   0.1s
# [CV] END max_depth=10, max_features=log2, min_samples_split=2, n_estimators=50; total time=   0.1s
# [CV] END max_depth=10, max_features=sqrt, min_samples_split=10, n_estimators=150; total time=   0.4s
# [CV] END max_depth=10, max_features=sqrt, min_samples_split=10, n_estimators=150; total time=   0.4s
# [CV] END max_depth=10, max_features=sqrt, min_samples_split=10, n_estimators=150; total time=   0.4s
# [CV] END max_depth=10, max_features=log2, min_samples_split=2, n_estimators=100; total time=   0.2s
# [CV] END max_depth=10, max_features=sqrt, min_samples_split=10, n_estimators=200; total time=   0.5s
# [CV] END max_depth=10, max_features=sqrt, min_samples_split=10, n_estimators=200; total time=   0.5s
# [CV] END max_depth=10, max_features=sqrt, min_samples_split=10, n_estimators=200; total time=   0.5s
# [CV] END max_depth=10, max_features=log2, min_samples_split=2, n_estimators=100; total time=   0.2s
# [CV] END max_depth=10, max_features=log2, min_samples_split=2, n_estimators=100; total time=   0.2s
# [CV] END max_depth=10, max_features=log2, min_samples_split=2, n_estimators=100; total time=   0.2s
# [CV] END max_depth=10, max_features=sqrt, min_samples_split=10, n_estimators=200; total time=   0.5s
# [CV] END max_depth=10, max_features=sqrt, min_samples_split=10, n_estimators=200; total time=   0.5s
# [CV] END max_depth=10, max_features=log2, min_samples_split=2, n_estimators=100; total time=   0.2s
# [CV] END max_depth=10, max_features=log2, min_samples_split=5, n_estimators=50; total time=   0.1s
# [CV] END max_depth=10, max_features=log2, min_samples_split=5, n_estimators=50; total time=   0.1s
# [CV] END max_depth=10, max_features=log2, min_samples_split=2, n_estimators=150; total time=   0.3s
# [CV] END max_depth=10, max_features=log2, min_samples_split=2, n_estimators=150; total time=   0.3s
# [CV] END max_depth=10, max_features=log2, min_samples_split=2, n_estimators=150; total time=   0.3s
# [CV] END max_depth=10, max_features=log2, min_samples_split=5, n_estimators=50; total time=   0.1s
# [CV] END max_depth=10, max_features=log2, min_samples_split=5, n_estimators=50; total time=   0.1s
# [CV] END max_depth=10, max_features=log2, min_samples_split=2, n_estimators=150; total time=   0.3s
# [CV] END max_depth=10, max_features=log2, min_samples_split=5, n_estimators=50; total time=   0.1s
# [CV] END max_depth=10, max_features=log2, min_samples_split=2, n_estimators=150; total time=   0.3s
# [CV] END max_depth=10, max_features=log2, min_samples_split=2, n_estimators=200; total time=   0.4s
# [CV] END max_depth=10, max_features=log2, min_samples_split=5, n_estimators=100; total time=   0.2s
# [CV] END max_depth=10, max_features=log2, min_samples_split=2, n_estimators=200; total time=   0.4s
# [CV] END max_depth=10, max_features=log2, min_samples_split=2, n_estimators=200; total time=   0.4s
# [CV] END max_depth=10, max_features=log2, min_samples_split=5, n_estimators=100; total time=   0.2s
# [CV] END max_depth=10, max_features=log2, min_samples_split=2, n_estimators=200; total time=   0.4s
# [CV] END max_depth=10, max_features=log2, min_samples_split=2, n_estimators=200; total time=   0.4s
# [CV] END max_depth=10, max_features=log2, min_samples_split=5, n_estimators=100; total time=   0.2s
# [CV] END max_depth=10, max_features=log2, min_samples_split=5, n_estimators=100; total time=   0.2s
# [CV] END max_depth=10, max_features=log2, min_samples_split=5, n_estimators=100; total time=   0.2s
# [CV] END max_depth=10, max_features=log2, min_samples_split=10, n_estimators=50; total time=   0.1s
# [CV] END max_depth=10, max_features=log2, min_samples_split=5, n_estimators=150; total time=   0.3s
# [CV] END max_depth=10, max_features=log2, min_samples_split=10, n_estimators=50; total time=   0.1s
# [CV] END max_depth=10, max_features=log2, min_samples_split=5, n_estimators=150; total time=   0.3s
# [CV] END max_depth=10, max_features=log2, min_samples_split=10, n_estimators=50; total time=   0.1s
# [CV] END max_depth=10, max_features=log2, min_samples_split=10, n_estimators=50; total time=   0.1s
# [CV] END max_depth=10, max_features=log2, min_samples_split=10, n_estimators=50; total time=   0.1s
# [CV] END max_depth=10, max_features=log2, min_samples_split=5, n_estimators=150; total time=   0.3s
# [CV] END max_depth=10, max_features=log2, min_samples_split=5, n_estimators=150; total time=   0.3s
# [CV] END max_depth=10, max_features=log2, min_samples_split=5, n_estimators=150; total time=   0.3s
# [CV] END max_depth=10, max_features=log2, min_samples_split=5, n_estimators=200; total time=   0.4s
# [CV] END max_depth=10, max_features=log2, min_samples_split=10, n_estimators=100; total time=   0.2s
# [CV] END max_depth=10, max_features=log2, min_samples_split=5, n_estimators=200; total time=   0.4s
# [CV] END max_depth=10, max_features=log2, min_samples_split=5, n_estimators=200; total time=   0.4s
# [CV] END max_depth=10, max_features=log2, min_samples_split=5, n_estimators=200; total time=   0.4s
# [CV] END max_depth=10, max_features=log2, min_samples_split=5, n_estimators=200; total time=   0.4s
# [CV] END max_depth=10, max_features=log2, min_samples_split=10, n_estimators=100; total time=   0.2s
# [CV] END max_depth=10, max_features=log2, min_samples_split=10, n_estimators=100; total time=   0.2s
# [CV] END max_depth=10, max_features=log2, min_samples_split=10, n_estimators=100; total time=   0.2s
# [CV] END max_depth=10, max_features=log2, min_samples_split=10, n_estimators=100; total time=   0.2s
# [CV] END max_depth=10, max_features=log2, min_samples_split=10, n_estimators=150; total time=   0.3s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=2, n_estimators=50; total time=   0.1s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=2, n_estimators=50; total time=   0.2s
# [CV] END max_depth=10, max_features=log2, min_samples_split=10, n_estimators=150; total time=   0.4s
# [CV] END max_depth=10, max_features=log2, min_samples_split=10, n_estimators=150; total time=   0.3s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=2, n_estimators=50; total time=   0.2s
# [CV] END max_depth=10, max_features=log2, min_samples_split=10, n_estimators=150; total time=   0.3s
# [CV] END max_depth=10, max_features=log2, min_samples_split=10, n_estimators=150; total time=   0.3s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=2, n_estimators=50; total time=   0.1s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=2, n_estimators=50; total time=   0.2s
# [CV] END max_depth=10, max_features=log2, min_samples_split=10, n_estimators=200; total time=   0.4s
# [CV] END max_depth=10, max_features=log2, min_samples_split=10, n_estimators=200; total time=   0.4s
# [CV] END max_depth=10, max_features=log2, min_samples_split=10, n_estimators=200; total time=   0.4s
# [CV] END max_depth=10, max_features=log2, min_samples_split=10, n_estimators=200; total time=   0.4s
# [CV] END max_depth=10, max_features=log2, min_samples_split=10, n_estimators=200; total time=   0.5s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=2, n_estimators=100; total time=   0.3s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=2, n_estimators=100; total time=   0.3s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=2, n_estimators=100; total time=   0.3s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=2, n_estimators=100; total time=   0.3s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=2, n_estimators=100; total time=   0.3s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=5, n_estimators=50; total time=   0.2s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=2, n_estimators=150; total time=   0.4s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=5, n_estimators=50; total time=   0.1s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=2, n_estimators=150; total time=   0.4s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=2, n_estimators=150; total time=   0.4s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=2, n_estimators=150; total time=   0.4s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=5, n_estimators=50; total time=   0.1s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=2, n_estimators=150; total time=   0.5s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=5, n_estimators=50; total time=   0.2s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=5, n_estimators=50; total time=   0.2s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=2, n_estimators=200; total time=   0.5s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=2, n_estimators=200; total time=   0.6s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=5, n_estimators=100; total time=   0.3s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=5, n_estimators=100; total time=   0.3s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=2, n_estimators=200; total time=   0.6s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=2, n_estimators=200; total time=   0.6s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=5, n_estimators=100; total time=   0.3s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=2, n_estimators=200; total time=   0.6s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=5, n_estimators=100; total time=   0.3s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=5, n_estimators=100; total time=   0.3s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=10, n_estimators=50; total time=   0.1s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=10, n_estimators=50; total time=   0.2s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=5, n_estimators=150; total time=   0.4s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=5, n_estimators=150; total time=   0.4s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=5, n_estimators=150; total time=   0.4s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=10, n_estimators=50; total time=   0.1s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=5, n_estimators=150; total time=   0.4s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=5, n_estimators=150; total time=   0.4s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=10, n_estimators=50; total time=   0.1s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=10, n_estimators=50; total time=   0.1s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=10, n_estimators=100; total time=   0.2s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=5, n_estimators=200; total time=   0.5s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=10, n_estimators=100; total time=   0.3s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=5, n_estimators=200; total time=   0.6s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=5, n_estimators=200; total time=   0.6s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=10, n_estimators=100; total time=   0.3s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=5, n_estimators=200; total time=   0.6s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=10, n_estimators=100; total time=   0.3s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=5, n_estimators=200; total time=   0.6s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=10, n_estimators=100; total time=   0.3s
# [CV] END max_depth=20, max_features=log2, min_samples_split=2, n_estimators=50; total time=   0.1s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=10, n_estimators=150; total time=   0.4s
# [CV] END max_depth=20, max_features=log2, min_samples_split=2, n_estimators=50; total time=   0.2s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=10, n_estimators=150; total time=   0.4s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=10, n_estimators=150; total time=   0.4s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=10, n_estimators=150; total time=   0.4s
# [CV] END max_depth=20, max_features=log2, min_samples_split=2, n_estimators=50; total time=   0.1s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=10, n_estimators=150; total time=   0.4s
# [CV] END max_depth=20, max_features=log2, min_samples_split=2, n_estimators=50; total time=   0.1s
# [CV] END max_depth=20, max_features=log2, min_samples_split=2, n_estimators=50; total time=   0.2s
# [CV] END max_depth=20, max_features=log2, min_samples_split=2, n_estimators=100; total time=   0.3s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=10, n_estimators=200; total time=   0.5s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=10, n_estimators=200; total time=   0.5s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=10, n_estimators=200; total time=   0.5s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=10, n_estimators=200; total time=   0.5s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=10, n_estimators=200; total time=   0.6s
# [CV] END max_depth=20, max_features=log2, min_samples_split=2, n_estimators=100; total time=   0.3s
# [CV] END max_depth=20, max_features=log2, min_samples_split=2, n_estimators=100; total time=   0.3s
# [CV] END max_depth=20, max_features=log2, min_samples_split=2, n_estimators=100; total time=   0.3s
# [CV] END max_depth=20, max_features=log2, min_samples_split=2, n_estimators=100; total time=   0.3s
# [CV] END max_depth=20, max_features=log2, min_samples_split=2, n_estimators=150; total time=   0.4s
# [CV] END max_depth=20, max_features=log2, min_samples_split=5, n_estimators=50; total time=   0.1s
# [CV] END max_depth=20, max_features=log2, min_samples_split=5, n_estimators=50; total time=   0.1s
# [CV] END max_depth=20, max_features=log2, min_samples_split=2, n_estimators=150; total time=   0.4s
# [CV] END max_depth=20, max_features=log2, min_samples_split=5, n_estimators=50; total time=   0.1s
# [CV] END max_depth=20, max_features=log2, min_samples_split=5, n_estimators=50; total time=   0.1s
# [CV] END max_depth=20, max_features=log2, min_samples_split=5, n_estimators=50; total time=   0.1s
# [CV] END max_depth=20, max_features=log2, min_samples_split=2, n_estimators=150; total time=   0.4s
# [CV] END max_depth=20, max_features=log2, min_samples_split=2, n_estimators=150; total time=   0.4s
# [CV] END max_depth=20, max_features=log2, min_samples_split=2, n_estimators=150; total time=   0.4s
# [CV] END max_depth=20, max_features=log2, min_samples_split=5, n_estimators=100; total time=   0.3s
# [CV] END max_depth=20, max_features=log2, min_samples_split=2, n_estimators=200; total time=   0.5s
# [CV] END max_depth=20, max_features=log2, min_samples_split=2, n_estimators=200; total time=   0.5s
# [CV] END max_depth=20, max_features=log2, min_samples_split=2, n_estimators=200; total time=   0.5s
# [CV] END max_depth=20, max_features=log2, min_samples_split=2, n_estimators=200; total time=   0.5s
# [CV] END max_depth=20, max_features=log2, min_samples_split=5, n_estimators=100; total time=   0.2s
# [CV] END max_depth=20, max_features=log2, min_samples_split=2, n_estimators=200; total time=   0.5s
# [CV] END max_depth=20, max_features=log2, min_samples_split=5, n_estimators=100; total time=   0.2s
# [CV] END max_depth=20, max_features=log2, min_samples_split=5, n_estimators=100; total time=   0.3s
# [CV] END max_depth=20, max_features=log2, min_samples_split=5, n_estimators=100; total time=   0.3s
# [CV] END max_depth=20, max_features=log2, min_samples_split=10, n_estimators=50; total time=   0.1s
# [CV] END max_depth=20, max_features=log2, min_samples_split=10, n_estimators=50; total time=   0.1s
# [CV] END max_depth=20, max_features=log2, min_samples_split=5, n_estimators=150; total time=   0.4s
# [CV] END max_depth=20, max_features=log2, min_samples_split=5, n_estimators=150; total time=   0.4s
# [CV] END max_depth=20, max_features=log2, min_samples_split=10, n_estimators=50; total time=   0.1s
# [CV] END max_depth=20, max_features=log2, min_samples_split=5, n_estimators=150; total time=   0.4s
# [CV] END max_depth=20, max_features=log2, min_samples_split=10, n_estimators=50; total time=   0.1s
# [CV] END max_depth=20, max_features=log2, min_samples_split=5, n_estimators=150; total time=   0.4s
# [CV] END max_depth=20, max_features=log2, min_samples_split=10, n_estimators=50; total time=   0.1s
# [CV] END max_depth=20, max_features=log2, min_samples_split=5, n_estimators=150; total time=   0.4s
# [CV] END max_depth=20, max_features=log2, min_samples_split=5, n_estimators=200; total time=   0.4s
# [CV] END max_depth=20, max_features=log2, min_samples_split=10, n_estimators=100; total time=   0.2s
# [CV] END max_depth=20, max_features=log2, min_samples_split=5, n_estimators=200; total time=   0.5s
# [CV] END max_depth=20, max_features=log2, min_samples_split=5, n_estimators=200; total time=   0.5s
# [CV] END max_depth=20, max_features=log2, min_samples_split=5, n_estimators=200; total time=   0.5s
# [CV] END max_depth=20, max_features=log2, min_samples_split=5, n_estimators=200; total time=   0.5s
# [CV] END max_depth=20, max_features=log2, min_samples_split=10, n_estimators=100; total time=   0.2s
# [CV] END max_depth=20, max_features=log2, min_samples_split=10, n_estimators=100; total time=   0.2s
# [CV] END max_depth=20, max_features=log2, min_samples_split=10, n_estimators=100; total time=   0.2s
# [CV] END max_depth=20, max_features=log2, min_samples_split=10, n_estimators=100; total time=   0.3s
# [CV] END max_depth=20, max_features=log2, min_samples_split=10, n_estimators=150; total time=   0.3s
# [CV] END max_depth=20, max_features=log2, min_samples_split=10, n_estimators=150; total time=   0.3s
# [CV] END max_depth=20, max_features=log2, min_samples_split=10, n_estimators=150; total time=   0.3s
# [CV] END max_depth=20, max_features=log2, min_samples_split=10, n_estimators=150; total time=   0.3s
# [CV] END max_depth=20, max_features=log2, min_samples_split=10, n_estimators=150; total time=   0.3s
# [CV] END max_depth=20, max_features=log2, min_samples_split=10, n_estimators=200; total time=   0.4s
# [CV] END max_depth=20, max_features=log2, min_samples_split=10, n_estimators=200; total time=   0.4s
# [CV] END max_depth=20, max_features=log2, min_samples_split=10, n_estimators=200; total time=   0.4s
# [CV] END max_depth=20, max_features=log2, min_samples_split=10, n_estimators=200; total time=   0.4s
# [CV] END max_depth=20, max_features=log2, min_samples_split=10, n_estimators=200; total time=   0.4s
# Saved model to: outputs/models/random_forest_tuned.pkl
#
# Running GridSearchCV for: XGBoost
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# [CV] END ......learning_rate=0.1, max_depth=3, subsample=0.5; total time=   0.0s
# [CV] END ......learning_rate=0.1, max_depth=3, subsample=0.5; total time=   0.0s
# [CV] END ......learning_rate=0.1, max_depth=3, subsample=0.5; total time=   0.0s
# [CV] END ......learning_rate=0.1, max_depth=3, subsample=0.5; total time=   0.0s
# [CV] END ......learning_rate=0.1, max_depth=3, subsample=0.5; total time=   0.0s
# [CV] END ......learning_rate=0.1, max_depth=3, subsample=0.7; total time=   0.0s
# [CV] END ........learning_rate=0.1, max_depth=3, subsample=1; total time=   0.0s
# [CV] END ......learning_rate=0.1, max_depth=3, subsample=0.7; total time=   0.0s
# [CV] END ........learning_rate=0.1, max_depth=3, subsample=1; total time=   0.0s
# [CV] END ......learning_rate=0.1, max_depth=3, subsample=0.7; total time=   0.0s
# [CV] END ......learning_rate=0.1, max_depth=3, subsample=0.7; total time=   0.0s
# [CV] END ......learning_rate=0.1, max_depth=3, subsample=0.7; total time=   0.0s
# [CV] END ........learning_rate=0.1, max_depth=3, subsample=1; total time=   0.0s
# [CV] END ........learning_rate=0.1, max_depth=3, subsample=1; total time=   0.0s
# [CV] END ........learning_rate=0.1, max_depth=3, subsample=1; total time=   0.0s
# [CV] END ......learning_rate=0.1, max_depth=5, subsample=0.5; total time=   0.0s
# [CV] END ......learning_rate=0.1, max_depth=5, subsample=0.5; total time=   0.0s
# [CV] END ......learning_rate=0.1, max_depth=5, subsample=0.5; total time=   0.0s
# [CV] END ......learning_rate=0.1, max_depth=5, subsample=0.7; total time=   0.0s
# [CV] END ......learning_rate=0.1, max_depth=5, subsample=0.5; total time=   0.0s
# [CV] END ......learning_rate=0.1, max_depth=5, subsample=0.7; total time=   0.0s
# [CV] END ......learning_rate=0.1, max_depth=5, subsample=0.7; total time=   0.1s
# [CV] END ......learning_rate=0.1, max_depth=5, subsample=0.7; total time=   0.0s
# [CV] END ......learning_rate=0.1, max_depth=5, subsample=0.5; total time=   0.1s
# [CV] END ......learning_rate=0.1, max_depth=5, subsample=0.7; total time=   0.0s
# [CV] END ........learning_rate=0.1, max_depth=5, subsample=1; total time=   0.1s
# [CV] END ........learning_rate=0.1, max_depth=5, subsample=1; total time=   0.0s
# [CV] END ......learning_rate=0.1, max_depth=7, subsample=0.5; total time=   0.1s
# [CV] END ......learning_rate=0.1, max_depth=7, subsample=0.5; total time=   0.1s
# [CV] END ......learning_rate=0.1, max_depth=7, subsample=0.5; total time=   0.1s
# [CV] END ......learning_rate=0.1, max_depth=7, subsample=0.7; total time=   0.1s
# [CV] END ........learning_rate=0.1, max_depth=5, subsample=1; total time=   0.0s
# [CV] END .....learning_rate=0.01, max_depth=3, subsample=0.5; total time=   0.0s
# [CV] END ........learning_rate=0.1, max_depth=7, subsample=1; total time=   0.1s
# [CV] END ........learning_rate=0.1, max_depth=5, subsample=1; total time=   0.0s
# [CV] END ......learning_rate=0.1, max_depth=7, subsample=0.7; total time=   0.1s
# [CV] END ........learning_rate=0.1, max_depth=5, subsample=1; total time=   0.1s
# [CV] END ........learning_rate=0.1, max_depth=7, subsample=1; total time=   0.1s
# [CV] END ........learning_rate=0.1, max_depth=7, subsample=1; total time=   0.1s
# [CV] END .....learning_rate=0.01, max_depth=3, subsample=0.5; total time=   0.0s
# [CV] END ......learning_rate=0.1, max_depth=7, subsample=0.5; total time=   0.1s
# [CV] END .....learning_rate=0.01, max_depth=3, subsample=0.5; total time=   0.0s
# [CV] END .....learning_rate=0.01, max_depth=3, subsample=0.7; total time=   0.0s
# [CV] END .....learning_rate=0.01, max_depth=3, subsample=0.5; total time=   0.0s
# [CV] END ........learning_rate=0.1, max_depth=7, subsample=1; total time=   0.1s
# [CV] END ......learning_rate=0.1, max_depth=7, subsample=0.7; total time=   0.1s
# [CV] END .....learning_rate=0.01, max_depth=3, subsample=0.7; total time=   0.0s
# [CV] END ......learning_rate=0.1, max_depth=7, subsample=0.5; total time=   0.1s
# [CV] END ......learning_rate=0.1, max_depth=7, subsample=0.7; total time=   0.1s
# [CV] END ......learning_rate=0.1, max_depth=7, subsample=0.7; total time=   0.1s
# [CV] END .....learning_rate=0.01, max_depth=3, subsample=0.7; total time=   0.0s
# [CV] END ........learning_rate=0.1, max_depth=7, subsample=1; total time=   0.1s
# [CV] END .....learning_rate=0.01, max_depth=3, subsample=0.7; total time=   0.0s
# [CV] END .......learning_rate=0.01, max_depth=3, subsample=1; total time=   0.0s
# [CV] END .....learning_rate=0.01, max_depth=3, subsample=0.5; total time=   0.0s
# [CV] END .....learning_rate=0.01, max_depth=3, subsample=0.7; total time=   0.0s
# [CV] END .......learning_rate=0.01, max_depth=3, subsample=1; total time=   0.0s
# [CV] END .......learning_rate=0.01, max_depth=3, subsample=1; total time=   0.0s
# [CV] END .....learning_rate=0.01, max_depth=5, subsample=0.5; total time=   0.0s
# [CV] END .......learning_rate=0.01, max_depth=3, subsample=1; total time=   0.0s
# [CV] END .......learning_rate=0.01, max_depth=3, subsample=1; total time=   0.0s
# [CV] END .....learning_rate=0.01, max_depth=5, subsample=0.5; total time=   0.1s
# [CV] END .....learning_rate=0.01, max_depth=5, subsample=0.5; total time=   0.1s
# [CV] END .....learning_rate=0.01, max_depth=5, subsample=0.7; total time=   0.1s
# [CV] END .......learning_rate=0.01, max_depth=5, subsample=1; total time=   0.0s
# [CV] END .....learning_rate=0.01, max_depth=5, subsample=0.7; total time=   0.1s
# [CV] END .......learning_rate=0.01, max_depth=5, subsample=1; total time=   0.1s
# [CV] END ....learning_rate=0.001, max_depth=3, subsample=0.5; total time=   0.0s
# [CV] END .....learning_rate=0.01, max_depth=7, subsample=0.5; total time=   0.1s
# [CV] END .....learning_rate=0.01, max_depth=5, subsample=0.5; total time=   0.0s
# [CV] END .....learning_rate=0.01, max_depth=7, subsample=0.7; total time=   0.1s
# [CV] END .....learning_rate=0.01, max_depth=5, subsample=0.5; total time=   0.1s
# [CV] END .....learning_rate=0.01, max_depth=7, subsample=0.7; total time=   0.1s
# [CV] END .......learning_rate=0.01, max_depth=5, subsample=1; total time=   0.1s
# [CV] END .....learning_rate=0.01, max_depth=5, subsample=0.7; total time=   0.1s
# [CV] END ....learning_rate=0.001, max_depth=3, subsample=0.5; total time=   0.0s
# [CV] END .....learning_rate=0.01, max_depth=5, subsample=0.7; total time=   0.1s
# [CV] END .......learning_rate=0.01, max_depth=5, subsample=1; total time=   0.0s
# [CV] END .......learning_rate=0.01, max_depth=7, subsample=1; total time=   0.1s
# [CV] END .....learning_rate=0.01, max_depth=5, subsample=0.7; total time=   0.1s
# [CV] END ....learning_rate=0.001, max_depth=3, subsample=0.7; total time=   0.0s
# [CV] END ......learning_rate=0.001, max_depth=3, subsample=1; total time=   0.0s
# [CV] END ....learning_rate=0.001, max_depth=3, subsample=0.5; total time=   0.0s
# [CV] END .......learning_rate=0.01, max_depth=5, subsample=1; total time=   0.0s
# [CV] END ......learning_rate=0.001, max_depth=3, subsample=1; total time=   0.0s
# [CV] END .....learning_rate=0.01, max_depth=7, subsample=0.5; total time=   0.1s
# [CV] END ......learning_rate=0.001, max_depth=5, subsample=1; total time=   0.0s
# [CV] END ....learning_rate=0.001, max_depth=5, subsample=0.5; total time=   0.1s
# [CV] END .....learning_rate=0.01, max_depth=7, subsample=0.7; total time=   0.1s
# [CV] END .......learning_rate=0.01, max_depth=7, subsample=1; total time=   0.1s
# [CV] END ....learning_rate=0.001, max_depth=5, subsample=0.7; total time=   0.1s
# [CV] END ......learning_rate=0.001, max_depth=3, subsample=1; total time=   0.0s
# [CV] END ....learning_rate=0.001, max_depth=3, subsample=0.7; total time=   0.0s
# [CV] END .......learning_rate=0.01, max_depth=7, subsample=1; total time=   0.1s
# [CV] END ....learning_rate=0.001, max_depth=3, subsample=0.7; total time=   0.1s
# [CV] END .....learning_rate=0.01, max_depth=7, subsample=0.5; total time=   0.1s
# [CV] END ......learning_rate=0.001, max_depth=3, subsample=1; total time=   0.0s
# [CV] END .....learning_rate=0.01, max_depth=7, subsample=0.5; total time=   0.1s
# [CV] END ......learning_rate=0.001, max_depth=5, subsample=1; total time=   0.1s
# [CV] END ....learning_rate=0.001, max_depth=3, subsample=0.7; total time=   0.0s
# [CV] END ....learning_rate=0.001, max_depth=3, subsample=0.5; total time=   0.0s
# [CV] END ....learning_rate=0.001, max_depth=5, subsample=0.5; total time=   0.1s
# [CV] END ....learning_rate=0.001, max_depth=5, subsample=0.5; total time=   0.1s
# [CV] END ....learning_rate=0.001, max_depth=5, subsample=0.7; total time=   0.1s
# [CV] END .....learning_rate=0.01, max_depth=7, subsample=0.7; total time=   0.1s
# [CV] END ....learning_rate=0.001, max_depth=3, subsample=0.7; total time=   0.0s
# [CV] END ......learning_rate=0.001, max_depth=3, subsample=1; total time=   0.0s
# [CV] END .......learning_rate=0.01, max_depth=7, subsample=1; total time=   0.1s
# [CV] END ......learning_rate=0.001, max_depth=5, subsample=1; total time=   0.0s
# [CV] END ....learning_rate=0.001, max_depth=3, subsample=0.5; total time=   0.0s
# [CV] END ....learning_rate=0.001, max_depth=7, subsample=0.5; total time=   0.1s
# [CV] END ....learning_rate=0.001, max_depth=7, subsample=0.5; total time=   0.1s
# [CV] END ....learning_rate=0.001, max_depth=5, subsample=0.7; total time=   0.0s
# [CV] END ....learning_rate=0.001, max_depth=5, subsample=0.7; total time=   0.1s
# [CV] END ....learning_rate=0.001, max_depth=5, subsample=0.5; total time=   0.1s
# [CV] END .....learning_rate=0.01, max_depth=7, subsample=0.5; total time=   0.1s
# [CV] END ......learning_rate=0.001, max_depth=5, subsample=1; total time=   0.0s
# [CV] END .....learning_rate=0.01, max_depth=7, subsample=0.7; total time=   0.1s
# [CV] END ......learning_rate=0.001, max_depth=5, subsample=1; total time=   0.0s
# [CV] END .......learning_rate=0.01, max_depth=7, subsample=1; total time=   0.1s
# [CV] END ....learning_rate=0.001, max_depth=5, subsample=0.7; total time=   0.0s
# [CV] END ....learning_rate=0.001, max_depth=7, subsample=0.5; total time=   0.1s
# [CV] END ....learning_rate=0.001, max_depth=7, subsample=0.5; total time=   0.1s
# [CV] END ....learning_rate=0.001, max_depth=5, subsample=0.5; total time=   0.1s
# [CV] END ....learning_rate=0.001, max_depth=7, subsample=0.5; total time=   0.1s
# [CV] END ....learning_rate=0.001, max_depth=7, subsample=0.7; total time=   0.1s
# [CV] END ....learning_rate=0.001, max_depth=7, subsample=0.7; total time=   0.1s
# [CV] END ....learning_rate=0.001, max_depth=7, subsample=0.7; total time=   0.1s
# [CV] END ....learning_rate=0.001, max_depth=7, subsample=0.7; total time=   0.1s
# [CV] END ....learning_rate=0.001, max_depth=7, subsample=0.7; total time=   0.1s
# [CV] END ......learning_rate=0.001, max_depth=7, subsample=1; total time=   0.1s
# [CV] END ......learning_rate=0.001, max_depth=7, subsample=1; total time=   0.1s
# [CV] END ......learning_rate=0.001, max_depth=7, subsample=1; total time=   0.1s
# [CV] END ......learning_rate=0.001, max_depth=7, subsample=1; total time=   0.1s
# [CV] END ......learning_rate=0.001, max_depth=7, subsample=1; total time=   0.1s
# Saved model to: outputs/models/xgboost_tuned.pkl
#
# Running GridSearchCV for: Support Vector Machine
# Fitting 5 folds for each of 81 candidates, totalling 405 fits
# [CV] END ..........C=0.1, degree=2, gamma=0.1, kernel=linear; total time=   0.1s
# [CV] END ..........C=0.1, degree=2, gamma=0.1, kernel=linear; total time=   0.2s
# [CV] END ..........C=0.1, degree=2, gamma=0.1, kernel=linear; total time=   0.2s
# [CV] END ..........C=0.1, degree=2, gamma=0.1, kernel=linear; total time=   0.2s
# ...
# [CV] END .............C=1, degree=3, gamma=10, kernel=linear; total time=   0.2s
# [CV] END .............C=1, degree=3, gamma=10, kernel=linear; total time=   0.2s
# [CV] END .............C=1, degree=3, gamma=10, kernel=linear; total time=   0.2s
# [CV] END .............C=1, degree=3, gamma=10, kernel=linear; total time=   0.2s
# [CV] END ................C=1, degree=3, gamma=10, kernel=rbf; total time=   0.6s
# [CV] END ................C=1, degree=3, gamma=1, kernel=poly; total time=   9.9s
# [CV] END ................C=1, degree=3, gamma=10, kernel=rbf; total time=   0.6s
# [CV] END .............C=0.1, degree=4, gamma=10, kernel=poly; total time=  42.4s
# [CV] END ................C=1, degree=3, gamma=10, kernel=rbf; total time=   0.6s
# [CV] END ................C=1, degree=3, gamma=10, kernel=rbf; total time=   0.6s
# [CV] END ................C=1, degree=3, gamma=10, kernel=rbf; total time=   0.6s
# [CV] END ...............C=1, degree=2, gamma=10, kernel=poly; total time= 1.8min
# [CV] END .............C=0.1, degree=4, gamma=10, kernel=poly; total time= 1.2min
# [CV] END ...............C=1, degree=2, gamma=10, kernel=poly; total time= 2.5min
# [CV] END ............C=1, degree=4, gamma=0.1, kernel=linear; total time=   0.3s
# [CV] END ............C=1, degree=4, gamma=0.1, kernel=linear; total time=   0.2s
# [CV] END ............C=1, degree=4, gamma=0.1, kernel=linear; total time=   0.2s
# [CV] END ............C=1, degree=4, gamma=0.1, kernel=linear; total time=   0.2s
# [CV] END ............C=1, degree=4, gamma=0.1, kernel=linear; total time=   0.2s
# [CV] END ...............C=1, degree=4, gamma=0.1, kernel=rbf; total time=   0.3s
# [CV] END ...............C=1, degree=4, gamma=0.1, kernel=rbf; total time=   0.3s
# [CV] END ...............C=1, degree=4, gamma=0.1, kernel=rbf; total time=   0.5s
# [CV] END ...............C=1, degree=4, gamma=0.1, kernel=rbf; total time=   0.3s
# [CV] END ...............C=1, degree=4, gamma=0.1, kernel=rbf; total time=   0.3s
# [CV] END ..............C=1, degree=4, gamma=0.1, kernel=poly; total time=   0.2s
# [CV] END ...............C=1, degree=2, gamma=10, kernel=poly; total time= 2.5min
# [CV] END ..............C=1, degree=4, gamma=0.1, kernel=poly; total time=   0.2s
# [CV] END ..............C=1, degree=4, gamma=0.1, kernel=poly; total time=   0.2s
# [CV] END ..............C=1, degree=4, gamma=0.1, kernel=poly; total time=   0.3s
# [CV] END ..............C=1, degree=4, gamma=0.1, kernel=poly; total time=   0.3s
# [CV] END ..............C=1, degree=4, gamma=1, kernel=linear; total time=   0.3s
# [CV] END ..............C=1, degree=4, gamma=1, kernel=linear; total time=   0.3s
# [CV] END ..............C=1, degree=4, gamma=1, kernel=linear; total time=   0.3s
# [CV] END ..............C=1, degree=4, gamma=1, kernel=linear; total time=   0.3s
# [CV] END ..............C=1, degree=4, gamma=1, kernel=linear; total time=   0.2s
# [CV] END .................C=1, degree=4, gamma=1, kernel=rbf; total time=   0.6s
# [CV] END .................C=1, degree=4, gamma=1, kernel=rbf; total time=   0.5s
# [CV] END ...............C=1, degree=2, gamma=10, kernel=poly; total time= 2.6min
# [CV] END .................C=1, degree=4, gamma=1, kernel=rbf; total time=   0.5s
# [CV] END ...............C=1, degree=2, gamma=10, kernel=poly; total time= 2.4min
# [CV] END .................C=1, degree=4, gamma=1, kernel=rbf; total time=   0.5s
# [CV] END .................C=1, degree=4, gamma=1, kernel=rbf; total time=   0.5s
# [CV] END ................C=1, degree=4, gamma=1, kernel=poly; total time=   7.0s
# [CV] END ................C=1, degree=4, gamma=1, kernel=poly; total time=   7.6s
# [CV] END .............C=1, degree=4, gamma=10, kernel=linear; total time=   0.2s
# [CV] END .............C=1, degree=4, gamma=10, kernel=linear; total time=   0.2s
# [CV] END ................C=1, degree=4, gamma=1, kernel=poly; total time=   8.0s
# [CV] END .............C=1, degree=4, gamma=10, kernel=linear; total time=   0.2s
# [CV] END .............C=1, degree=4, gamma=10, kernel=linear; total time=   0.3s
# [CV] END .............C=1, degree=4, gamma=10, kernel=linear; total time=   0.2s
# [CV] END ................C=1, degree=4, gamma=1, kernel=poly; total time=   8.6s
# [CV] END ................C=1, degree=4, gamma=10, kernel=rbf; total time=   0.6s
# [CV] END ................C=1, degree=4, gamma=10, kernel=rbf; total time=   0.6s
# [CV] END ................C=1, degree=4, gamma=10, kernel=rbf; total time=   0.5s
# [CV] END ................C=1, degree=4, gamma=10, kernel=rbf; total time=   0.6s
# [CV] END ................C=1, degree=4, gamma=10, kernel=rbf; total time=   0.5s
# [CV] END ................C=1, degree=4, gamma=1, kernel=poly; total time=   6.8s
# [CV] END ...............C=1, degree=4, gamma=10, kernel=poly; total time= 1.2min
# [CV] END .............C=0.1, degree=3, gamma=10, kernel=poly; total time= 4.3min
# [CV] END ...........C=10, degree=2, gamma=0.1, kernel=linear; total time=   0.6s
# [CV] END ...........C=10, degree=2, gamma=0.1, kernel=linear; total time=   0.6s
# [CV] END ...........C=10, degree=2, gamma=0.1, kernel=linear; total time=   0.5s
# [CV] END ...........C=10, degree=2, gamma=0.1, kernel=linear; total time=   0.5s
# [CV] END ...........C=10, degree=2, gamma=0.1, kernel=linear; total time=   0.5s
# [CV] END ..............C=10, degree=2, gamma=0.1, kernel=rbf; total time=   0.4s
# [CV] END ..............C=10, degree=2, gamma=0.1, kernel=rbf; total time=   0.3s
# [CV] END ..............C=10, degree=2, gamma=0.1, kernel=rbf; total time=   0.4s
# [CV] END ..............C=10, degree=2, gamma=0.1, kernel=rbf; total time=   0.4s
# [CV] END ..............C=10, degree=2, gamma=0.1, kernel=rbf; total time=   0.4s
# [CV] END .............C=10, degree=2, gamma=0.1, kernel=poly; total time=   0.3s
# [CV] END .............C=10, degree=2, gamma=0.1, kernel=poly; total time=   0.3s
# [CV] END .............C=10, degree=2, gamma=0.1, kernel=poly; total time=   0.3s
# [CV] END .............C=10, degree=2, gamma=0.1, kernel=poly; total time=   0.3s
# [CV] END .............C=10, degree=2, gamma=0.1, kernel=poly; total time=   0.3s
# [CV] END .............C=10, degree=2, gamma=1, kernel=linear; total time=   0.5s
# [CV] END .............C=10, degree=2, gamma=1, kernel=linear; total time=   0.5s
# [CV] END .............C=10, degree=2, gamma=1, kernel=linear; total time=   0.5s
# [CV] END .............C=10, degree=2, gamma=1, kernel=linear; total time=   0.6s
# [CV] END .............C=10, degree=2, gamma=1, kernel=linear; total time=   0.5s
# [CV] END ................C=10, degree=2, gamma=1, kernel=rbf; total time=   0.6s
# [CV] END ................C=10, degree=2, gamma=1, kernel=rbf; total time=   0.6s
# [CV] END ................C=10, degree=2, gamma=1, kernel=rbf; total time=   0.6s
# [CV] END ................C=10, degree=2, gamma=1, kernel=rbf; total time=   0.6s
# [CV] END .............C=0.1, degree=3, gamma=10, kernel=poly; total time= 4.5min
# [CV] END ................C=10, degree=2, gamma=1, kernel=rbf; total time=   0.6s
# [CV] END ...............C=1, degree=4, gamma=10, kernel=poly; total time= 1.7min
# [CV] END ...............C=10, degree=2, gamma=1, kernel=poly; total time=  11.3s
# [CV] END ...............C=10, degree=2, gamma=1, kernel=poly; total time=  10.9s
# [CV] END ...............C=1, degree=4, gamma=10, kernel=poly; total time= 1.9min
# [CV] END ...............C=1, degree=4, gamma=10, kernel=poly; total time= 1.9min
# [CV] END ............C=10, degree=2, gamma=10, kernel=linear; total time=   0.6s
# [CV] END ............C=10, degree=2, gamma=10, kernel=linear; total time=   0.5s
# [CV] END ............C=10, degree=2, gamma=10, kernel=linear; total time=   0.6s
# [CV] END ...............C=10, degree=2, gamma=1, kernel=poly; total time=  11.0s
# [CV] END ............C=10, degree=2, gamma=10, kernel=linear; total time=   0.5s
# [CV] END ............C=10, degree=2, gamma=10, kernel=linear; total time=   0.5s
# [CV] END ...............C=10, degree=2, gamma=10, kernel=rbf; total time=   0.7s
# [CV] END ...............C=10, degree=2, gamma=10, kernel=rbf; total time=   0.6s
# [CV] END ...............C=10, degree=2, gamma=10, kernel=rbf; total time=   0.6s
# [CV] END ...............C=10, degree=2, gamma=10, kernel=rbf; total time=   0.7s
# [CV] END ...............C=10, degree=2, gamma=10, kernel=rbf; total time=   0.6s
# [CV] END ...............C=10, degree=2, gamma=1, kernel=poly; total time=  11.3s
# [CV] END ...............C=10, degree=2, gamma=1, kernel=poly; total time=  12.3s
# [CV] END ...............C=1, degree=4, gamma=10, kernel=poly; total time=  52.0s
# [CV] END .............C=0.1, degree=3, gamma=10, kernel=poly; total time= 5.3min
# [CV] END .............C=0.1, degree=3, gamma=10, kernel=poly; total time= 4.2min
# [CV] END ...........C=10, degree=3, gamma=0.1, kernel=linear; total time=   0.5s
# [CV] END ...........C=10, degree=3, gamma=0.1, kernel=linear; total time=   0.5s
# [CV] END ...........C=10, degree=3, gamma=0.1, kernel=linear; total time=   0.5s
# [CV] END ...........C=10, degree=3, gamma=0.1, kernel=linear; total time=   0.6s
# [CV] END ...........C=10, degree=3, gamma=0.1, kernel=linear; total time=   0.5s
# [CV] END ..............C=10, degree=3, gamma=0.1, kernel=rbf; total time=   0.4s
# [CV] END ..............C=10, degree=3, gamma=0.1, kernel=rbf; total time=   0.4s
# [CV] END ..............C=10, degree=3, gamma=0.1, kernel=rbf; total time=   0.4s
# [CV] END ..............C=10, degree=3, gamma=0.1, kernel=rbf; total time=   0.4s
# [CV] END ..............C=10, degree=3, gamma=0.1, kernel=rbf; total time=   0.4s
# [CV] END .............C=10, degree=3, gamma=0.1, kernel=poly; total time=   0.3s
# [CV] END .............C=10, degree=3, gamma=0.1, kernel=poly; total time=   0.3s
# [CV] END .............C=10, degree=3, gamma=0.1, kernel=poly; total time=   0.4s
# [CV] END .............C=10, degree=3, gamma=0.1, kernel=poly; total time=   0.3s
# [CV] END .............C=10, degree=3, gamma=0.1, kernel=poly; total time=   0.4s
# [CV] END .............C=10, degree=3, gamma=1, kernel=linear; total time=   0.6s
# [CV] END .............C=10, degree=3, gamma=1, kernel=linear; total time=   0.5s
# [CV] END .............C=10, degree=3, gamma=1, kernel=linear; total time=   0.6s
# [CV] END .............C=10, degree=3, gamma=1, kernel=linear; total time=   0.5s
# [CV] END .............C=10, degree=3, gamma=1, kernel=linear; total time=   0.5s
# [CV] END .............C=0.1, degree=3, gamma=10, kernel=poly; total time= 5.1min
# [CV] END ................C=10, degree=3, gamma=1, kernel=rbf; total time=   0.6s
# [CV] END ................C=10, degree=3, gamma=1, kernel=rbf; total time=   0.6s
# [CV] END ................C=10, degree=3, gamma=1, kernel=rbf; total time=   0.6s
# [CV] END ................C=10, degree=3, gamma=1, kernel=rbf; total time=   0.6s
# [CV] END ................C=10, degree=3, gamma=1, kernel=rbf; total time=   0.7s
# [CV] END ...............C=10, degree=3, gamma=1, kernel=poly; total time= 1.2min
# [CV] END ...............C=10, degree=3, gamma=1, kernel=poly; total time= 1.4min
# [CV] END ...............C=1, degree=3, gamma=10, kernel=poly; total time= 9.7min
# [CV] END ...............C=10, degree=3, gamma=1, kernel=poly; total time= 1.0min
# [CV] END ............C=10, degree=3, gamma=10, kernel=linear; total time=   0.5s
# [CV] END ............C=10, degree=3, gamma=10, kernel=linear; total time=   0.5s
# [CV] END ............C=10, degree=3, gamma=10, kernel=linear; total time=   0.5s
# [CV] END ............C=10, degree=3, gamma=10, kernel=linear; total time=   0.5s
# [CV] END ............C=10, degree=3, gamma=10, kernel=linear; total time=   0.5s
# [CV] END ...............C=10, degree=3, gamma=10, kernel=rbf; total time=   0.7s
# [CV] END ...............C=10, degree=3, gamma=10, kernel=rbf; total time=   0.7s
# [CV] END ...............C=10, degree=3, gamma=10, kernel=rbf; total time=   0.7s
# [CV] END ...............C=10, degree=3, gamma=10, kernel=rbf; total time=   0.6s
# [CV] END ...............C=10, degree=3, gamma=10, kernel=rbf; total time=   0.6s
# [CV] END ...............C=10, degree=3, gamma=1, kernel=poly; total time= 1.1min
# [CV] END ...............C=1, degree=3, gamma=10, kernel=poly; total time=10.3min
# [CV] END ...............C=10, degree=3, gamma=1, kernel=poly; total time= 1.0min
# [CV] END ...............C=1, degree=3, gamma=10, kernel=poly; total time=14.4min
# [CV] END ...............C=1, degree=3, gamma=10, kernel=poly; total time=17.2min
# [CV] END ...........C=10, degree=4, gamma=0.1, kernel=linear; total time=   0.5s
# [CV] END ...........C=10, degree=4, gamma=0.1, kernel=linear; total time=   0.5s
# [CV] END ...........C=10, degree=4, gamma=0.1, kernel=linear; total time=   0.5s
# [CV] END ...........C=10, degree=4, gamma=0.1, kernel=linear; total time=   0.5s
# [CV] END ...........C=10, degree=4, gamma=0.1, kernel=linear; total time=   0.5s
# [CV] END ..............C=10, degree=4, gamma=0.1, kernel=rbf; total time=   0.3s
# [CV] END ..............C=10, degree=4, gamma=0.1, kernel=rbf; total time=   0.3s
# [CV] END ..............C=10, degree=4, gamma=0.1, kernel=rbf; total time=   0.4s
# [CV] END ..............C=10, degree=4, gamma=0.1, kernel=rbf; total time=   0.4s
# [CV] END ..............C=10, degree=4, gamma=0.1, kernel=rbf; total time=   0.4s
# [CV] END .............C=10, degree=4, gamma=0.1, kernel=poly; total time=   0.3s
# [CV] END .............C=10, degree=4, gamma=0.1, kernel=poly; total time=   0.3s
# [CV] END .............C=10, degree=4, gamma=0.1, kernel=poly; total time=   0.3s
# [CV] END .............C=10, degree=4, gamma=0.1, kernel=poly; total time=   0.4s
# [CV] END .............C=10, degree=4, gamma=0.1, kernel=poly; total time=   0.3s
# [CV] END .............C=10, degree=4, gamma=1, kernel=linear; total time=   0.5s
# [CV] END .............C=10, degree=4, gamma=1, kernel=linear; total time=   0.5s
# [CV] END .............C=10, degree=4, gamma=1, kernel=linear; total time=   0.5s
# [CV] END .............C=10, degree=4, gamma=1, kernel=linear; total time=   0.5s
# [CV] END .............C=10, degree=4, gamma=1, kernel=linear; total time=   0.5s
# [CV] END ................C=10, degree=4, gamma=1, kernel=rbf; total time=   0.5s
# [CV] END ................C=10, degree=4, gamma=1, kernel=rbf; total time=   0.6s
# [CV] END ................C=10, degree=4, gamma=1, kernel=rbf; total time=   0.5s
# [CV] END ................C=10, degree=4, gamma=1, kernel=rbf; total time=   0.6s
# [CV] END ................C=10, degree=4, gamma=1, kernel=rbf; total time=   0.6s
# [CV] END ...............C=10, degree=4, gamma=1, kernel=poly; total time=  16.4s
# [CV] END ...............C=10, degree=4, gamma=1, kernel=poly; total time=  20.4s
# [CV] END ...............C=1, degree=3, gamma=10, kernel=poly; total time=18.1min
# [CV] END ...............C=10, degree=4, gamma=1, kernel=poly; total time=  13.3s
# [CV] END ...............C=10, degree=4, gamma=1, kernel=poly; total time=  20.5s
# [CV] END ............C=10, degree=4, gamma=10, kernel=linear; total time=   0.5s
# [CV] END ............C=10, degree=4, gamma=10, kernel=linear; total time=   0.5s
# [CV] END ............C=10, degree=4, gamma=10, kernel=linear; total time=   0.5s
# [CV] END ............C=10, degree=4, gamma=10, kernel=linear; total time=   0.5s
# [CV] END ............C=10, degree=4, gamma=10, kernel=linear; total time=   0.5s
# [CV] END ...............C=10, degree=4, gamma=10, kernel=rbf; total time=   0.6s
# [CV] END ...............C=10, degree=4, gamma=10, kernel=rbf; total time=   0.7s
# [CV] END ...............C=10, degree=4, gamma=10, kernel=rbf; total time=   0.6s
# [CV] END ...............C=10, degree=4, gamma=10, kernel=rbf; total time=   0.7s
# [CV] END ...............C=10, degree=4, gamma=10, kernel=rbf; total time=   0.6s
# [CV] END ...............C=10, degree=4, gamma=1, kernel=poly; total time=  21.0s
# [CV] END ..............C=10, degree=4, gamma=10, kernel=poly; total time= 2.0min
# [CV] END ..............C=10, degree=4, gamma=10, kernel=poly; total time= 1.9min
# [CV] END ..............C=10, degree=4, gamma=10, kernel=poly; total time= 4.4min
# [CV] END ..............C=10, degree=4, gamma=10, kernel=poly; total time= 3.3min
# [CV] END ..............C=10, degree=4, gamma=10, kernel=poly; total time= 2.8min

# %%
print(results)
print(best_param)
# Out:
# {'Random Forest': 0.5714285714285714, 'XGBoost': 0.5891238670694864}
# {'Random Forest': {'max_depth': 10, 'max_features': 'log2', 'min_samples_split': 10, 'n_estimators': 150}, 'XGBoost': {'learning_rate': 0.1, 'max_depth': 3, 'subsample': 0.7}}
